# %% [markdown]
# ## Guided Capstone Project Report

# %% [markdown]
# [Intro](#intro)<br>
# After looking in to Big Mountain ski resort we have concluded that Big Mountain has the ability to adjust their prices which reflect similar priced to other resorts which contain similar attributes. recall that their pricing  is currently the average price of the neighboring resorts nearest Big mountain, being \\$81 for adults both on weekends and week days. After analyzing all ski resorts in the united states and taking into account the possible changes which Big Mountain is willing and able to make, we focused on four possible changes that will positively impact revenue and cut maintenance cost.
# 1. Close up to 10 of the least used runs. The number of runs is the only parameter varying.
# 2. Adding a run that increases the vertical drop by 150 feet and installing an additional chair lift.
# 3. Adding 2 acres of snow making in addition to increasing vertical drop.
# 4. Increasing the longest run by .2 miles and guaranteeing its snow coverage by adding 4 acres of snow making capability.<br>

# %% [markdown]
# [1. Close up to 10 of Big Mountains least used runs](#main)<br>
# before getting into each scenario, we must note that we are missing data on two crucial factors which may impact the current outcomes. currently, we are missing data on maintenance cost for ski lifts and snow making, we only know how snow making and ski lifts impact customers willingness to purchase a ticket. with that being said, we will dive into each of the four scenario listed above. <br>
# Big mountain is willing to close up to ten of its least used runs in efforts to save on maintenance cost of the runs. as said before, we do not know the maintenance cost for a run however, we where able to make a decisions without factoring this information in. first, it was discovered that closing one run has no impact on charging a competitive price so its advisable that Big Mountain does so as it yields instant saving upfront with little changes. Big mountain however, is willing to close up to ten so we created a plot to see the impact of run closures which are shown below in figure 1
# <h2><center>Figure 1</center></h2>
#
# ![Screen%20Shot%202021-03-06%20at%202.51.55%20PM.png](attachment:Screen%20Shot%202021-03-06%20at%202.51.55%20PM.png)
#
# Figure 1 above contains two different graphs, the first one on the left tracks the impact cost of one ticket as Big Mountain closed up to ten runs and the graph on the right indicates the loss of revenue as each run is closed if the resort meets a projected 350,000 visitors staying for five days. as we can see, closing one run has no impact on the ticket price or annual revenue however, closing two to three runs does mean a loss of about \\$2,000,000 to \\$2,550,000 this season respectively. closing three to five runs yields a loss of \\2,550,000 in the season so if Big Mountain opts to close 3 runs its recommended to close five instead since it holds the same loss of revenue. closing six to eight runs all yield a loss of \\$3,550,000 a season. since we are not given the maintenance cost of runs, we cannot give concise recommendation as to how many run closures yield an optimal saving.

# %% [markdown]
# [Adding a run that increases the vertical drop by 150 feet and installing an additional chair lift](#main)<br>
# In this scenario, Big Mountain will increase its longest run 150 feet. figure 2 below shows a bar graph of the vertical drops from all the resorts in the United States
# <h2><center>Figure 2</center></h2>
#
# ![Screen%20Shot%202021-03-06%20at%207.28.28%20PM.png](attachment:Screen%20Shot%202021-03-06%20at%207.28.28%20PM.png)
#
# the dashed red line indicates the longest run Big Mountain contains, which is just under 3.5 miles. as you can see, Big Mountain's longest run is significantly longer than the average, adding more to that run will only help. We discovered that in this case, increasing the longest run by 150 feet and adding the new ski lift will allow Big Mountain to increase its ticket price by \\$9.42 resulting in an overall admission of \\$90.42 and would yield an additional \\$16,485,507 in retinue this season. this retinue includes the cost of building the ski lift however, its excluding the maintenance cost since we where not given the data.

# %% [markdown]
# [Adding 2 acres of snow making after increasing vertical drop](#main)<br>
# in this case, we predicted the potential augmentation of ticket price if Big Mountain also created two acres of snow for the extra 150 feet. It was concluded that after the extension of the longest run along with creating two acres of snow, Big mountain will be able to sell an admission for \\$11.04 more than it currently is however, the impact that the snow making has is only  \\$1.62 meaning that the additional 2 acres of snow making will provide Big Mountain with \\$2,840,580 of revenue this year. Since we do not have additional information as to the cost of making snow, we can not conclude wether or not making an additional 2 acres of snow is profitable or not. My recommendation of making snow is dependent on the cost.

# %% [markdown]
# [Increasing the longest run by 0.2 miles and adding 4 acres of snow making capability.](#main)<br>
# Our model indicated that increasing the longest run by 0.2 miles and adding 4 acres of snow making would have no impact on the ability to raise admission prices per adult so its not advised to do so. increasing the longest run by 0.2 miles and adding 4 acres of snow making only increases the expense os Big Mountain.
